# %% [markdown]
# ![mlp1.jpeg](attachment:mlp1.jpeg)
# ![mlp2.jpeg](attachment:mlp2.jpeg)
# ![mlp3.jpeg](attachment:mlp3.jpeg)
# ![mlp4.jpeg](attachment:mlp4.jpeg)
# ![mlp5.jpeg](attachment:mlp5.jpeg)
# ![mlp6.jpeg](attachment:mlp6.jpeg)
# ![mlp7.jpeg](attachment:mlp7.jpeg)
# ![mlp8.jpeg](attachment:mlp8.jpeg)
