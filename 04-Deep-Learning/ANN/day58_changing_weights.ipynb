# %%
x1 = 5 
x2 = 10

w1 = 0.1    #observe the by changing the weights, the output will change
w2 = 0.9

b = 2

z = x1 * w1 + x2 * w2 + b
print("Output:", z)
# Out:
# Output: 21.0

# %% [markdown]
#               Neural Network
#
# Input
#   ↓
# x1 ──× w1 ──┐
#              ├──→ + Bias ──→ Activation ──→ Output
# x2 ──× w2 ──┘
