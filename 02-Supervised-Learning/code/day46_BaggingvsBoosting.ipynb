# %% [markdown]
# # Bagging and Boosting

# %% [markdown]
# ![baggingvsboosting.jpeg](attachment:baggingvsboosting.jpeg)

# %% [markdown]
# ### simply for the image import copy the image and paste in markdown --
